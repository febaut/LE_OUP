# %%
from Lexicon import Lemma, Lexicon
import itertools
import json

# %%
input_json = './Data/sample_parsed_sentences.json'
output_json = './Data/sample_lexicon.json'

"""
Within the corpus, several duplicate tokens are found, as if each sentence had been processed twice. 
If these elements were kept the frequency counts would be distorted, so in my solution, 
I took the option of removing duplicated items for each sentence. 

As an example, the following token '2019' appears twice while in its sentece it appears only once. 

"sentence_text": "2019 жылы 27 желтоқсанда Президент \"Қазақстан Республикасының кейбір заңнамалық актілеріне қылмыстық, 
қылмыстық іс жүргізу заңнамасын жетілдіру және жеке адамның құқықтарын қорғауды күшейту 
мәселелері бойынша өзгерістер мен толықтырулар енгізу туралы\" Заңға қол қойды."

   {
          "id": "1",
          "text": "2019",
          "lemma": "2019",
          "pos": "NUM",
          "pos_finegrained": "num",
          "feats": "NumType=Ord",
          "start_char": "0",
          "end_char": "4"
        },
"""

# This function takes a each token in the json file as input and reformats it into a dictionary to create instances of the class Lemma.
# Some fields like id, start_char and end_char are taken to filter duplicated tokens per sentence. 
def preprocess_sentences(sentence):
    lemma_instances = []
    for token in sentence:
        lemma_entry = {'id': int(token['id']),
                'lemma': token['lemma'],
                'pos': [token['pos']],
                'morph_features': [token['feats']],
                # Takes the word and initializes the frequency counter with 1. 
                'word_forms': {token['text']: {'frequency':1}},
                "start_char": int(token['start_char']),
                "end_char": int(token['end_char'])}
        
        lemma_instances.append(Lemma(**lemma_entry))
    
    return list(set(lemma_instances))

# Creating an instance of the class `Lexicon` and initializing it with a set of `Lemma` objects. 
# The `Lemma` objects are created by iterating over the tokens in the JSON input file reformatting them into a dictionary using the `preprocess_sentences` function. 
# The resulting list of `Lemma` objects is then added to the `lemma_set` parameter of the `Lexicon` constructor.

lexicon = Lexicon(lemma_set=list(itertools.chain.from_iterable([preprocess_sentences(sentence['tokens']) for sentence in json.load(open(input_json, encoding='utf-8'))['sentences']])))

# %%
### Optional testing ###
def test_consistency():
    # Creating two lists to evaluate that the solution is working as expected 
    # `total_lemmas` and `total_word_forms`
    total_lemmas = [token['lemma'] for sentence in json.load(open(input_json, encoding='utf-8'))['sentences'] for token in sentence['tokens']]
    total_word_forms = [token['text'] for sentence in json.load(open(input_json, encoding='utf-8'))['sentences'] for token in sentence['tokens']]

    print(f"""
    Input file:
    Total lemmas: {len(total_lemmas)}
    Total unique lemmas: {len(set(total_lemmas))}
    Total word forms: {len(total_word_forms)}
    Total unique word forms: {len(set(total_word_forms))}
    """)

    # Checking if the total of unique lemmas in the `lexicon` is equal to the length of the set of unique lemmas in the input JSON file.
    assert lexicon.get_total_unique_lemmas() == len(set(total_lemmas))
    assert lexicon.get_total_unique_wf() == len(set(total_word_forms))

# comment/uncomment to avoid/excecute the previous test function prior to export.
#test_consistency()

# Calling the class method to export the lexicon  to a JSON file. 
lexicon.export_to_json(output_json)
# Out:
# Lexicon exported to: ./Data/sample_lexicon.json

# %%
lexicon
# Out:
# Lemma: ", Info: lemma='"' lemma_freq=6 pos=['PUNCT'] morph_features=[None] word_forms={'"': {'frequency': 6}}
# Lemma: күшейт, Info: lemma='күшейт' lemma_freq=1 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger'] word_forms={'күшейту': {'frequency': 1}}
# Lemma: жетілдір, Info: lemma='жетілдір' lemma_freq=1 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger'] word_forms={'жетілдіру': {'frequency': 1}}
# Lemma: жеке, Info: lemma='жеке' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'жеке': {'frequency': 1}}
# Lemma: және, Info: lemma='және' lemma_freq=2 pos=['CCONJ'] morph_features=[None] word_forms={'және': {'frequency': 2}}
# Lemma: іс, Info: lemma='іс' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'іс': {'frequency': 1}}
# Lemma: желтоқсан, Info: lemma='желтоқсан' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc'] word_forms={'желтоқсанда': {'frequency': 1}}
# Lemma: енгіз, Info: lemma='енгіз' lemma_freq=3 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger', 'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Pass'] word_forms={'енгізу': {'frequency': 2}, 'енгізілді': {'frequency': 1}}
# Lemma: 2019, Info: lemma='2019' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Ord'] word_forms={'2019': {'frequency': 1}}
# Lemma: қылмыстық, Info: lemma='қылмыстық' lemma_freq=2 pos=['ADJ'] morph_features=[None] word_forms={'қылмыстық': {'frequency': 2}}
# Lemma: қой, Info: lemma='қой' lemma_freq=1 pos=['VERB'] morph_features=['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'] word_forms={'қойды': {'frequency': 1}}
# Lemma: құқық, Info: lemma='құқық' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Acc|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'құқықтарын': {'frequency': 1}}
# Lemma: толықтыру, Info: lemma='толықтыру' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Nom|Number=Plur'] word_forms={'толықтырулар': {'frequency': 2}}
# Lemma: жыл, Info: lemma='жыл' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3', 'Case=Gen'] word_forms={'жылы': {'frequency': 1}, 'жылдың': {'frequency': 1}}
# Lemma: кейбір, Info: lemma='кейбір' lemma_freq=2 pos=['ADJ', 'DET'] morph_features=[None, 'PronType=Tot'] word_forms={'кейбір': {'frequency': 2}}
# Lemma: акт, Info: lemma='акт' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Ins|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3', 'Case=Dat|Number=Plur'] word_forms={'актілеріне': {'frequency': 1}, 'актілерге': {'frequency': 1}}
# Lemma: Қазақстан, Info: lemma='Қазақстан' lemma_freq=2 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'Қазақстан': {'frequency': 2}}
# Lemma: заңнамалық, Info: lemma='заңнамалық' lemma_freq=2 pos=['ADJ'] morph_features=[None] word_forms={'заңнамалық': {'frequency': 2}}
# Lemma: адам, Info: lemma='адам' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Gen'] word_forms={'адамның': {'frequency': 1}}
# Lemma: қол, Info: lemma='қол' lemma_freq=1 pos=['X'] morph_features=[None] word_forms={'қол': {'frequency': 1}}
# Lemma: заңнама, Info: lemma='заңнама' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'заңнамасын': {'frequency': 1}}
# Lemma: мәселе, Info: lemma='мәселе' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3', 'Case=Nom|Number=Plur|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'мәселелері': {'frequency': 2}}
# Lemma: жүр, Info: lemma='жүр' lemma_freq=2 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger'] word_forms={'жүргізу': {'frequency': 2}}
# Lemma: 27, Info: lemma='27' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Ord'] word_forms={'27': {'frequency': 1}}
# Lemma: ,, Info: lemma=',' lemma_freq=7 pos=['PUNCT'] morph_features=[None] word_forms={',': {'frequency': 7}}
# Lemma: ., Info: lemma='.' lemma_freq=7 pos=['PUNCT'] morph_features=[None] word_forms={'.': {'frequency': 7}}
# Lemma: мен, Info: lemma='мен' lemma_freq=4 pos=['CCONJ'] morph_features=[None] word_forms={'мен': {'frequency': 4}}
# Lemma: заң, Info: lemma='заң' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Dat', 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'Заңға': {'frequency': 1}, 'Заңы': {'frequency': 1}}
# Lemma: бойынша, Info: lemma='бойынша' lemma_freq=3 pos=['ADP'] morph_features=[None] word_forms={'бойынша': {'frequency': 3}}
# Lemma: қорғау, Info: lemma='қорғау' lemma_freq=1 pos=['VERB'] morph_features=['Case=Acc|VerbForm=Ger'] word_forms={'қорғауды': {'frequency': 1}}
# Lemma: президент, Info: lemma='президент' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Nom', 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'Президент': {'frequency': 1}, 'президенті': {'frequency': 1}}
# Lemma: республика, Info: lemma='республика' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Gen|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'Республикасының': {'frequency': 1}}
# Lemma: өзгеріс, Info: lemma='өзгеріс' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Nom|Number=Plur'] word_forms={'өзгерістер': {'frequency': 2}}
# Lemma: турал, Info: lemma='турал' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'туралы': {'frequency': 2}}
# Lemma: дайын, Info: lemma='дайын' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'дайын': {'frequency': 1}}
# Lemma: де, Info: lemma='де' lemma_freq=1 pos=['VERB'] morph_features=['Aspect=Perf|VerbForm=Conv'] word_forms={'деп': {'frequency': 1}}
# Lemma: проце, Info: lemma='проце' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'процесі': {'frequency': 1}}
# Lemma: өкіл, Info: lemma='өкіл' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Gen|Number[psor]=Plur,Sing|Person[psor]=3', 'Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'өкілінің': {'frequency': 1}, 'өкілі': {'frequency': 1}}
# Lemma: қажетті, Info: lemma='қажетті' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'қажетті': {'frequency': 1}}
# Lemma: үшін, Info: lemma='үшін' lemma_freq=1 pos=['ADP'] morph_features=[None] word_forms={'үшін': {'frequency': 1}}
# Lemma: ара, Info: lemma='ара' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'арасындағы': {'frequency': 1}}
# Lemma: хабарла, Info: lemma='хабарла' lemma_freq=1 pos=['VERB'] morph_features=['Tense=Past|VerbForm=Fin'] word_forms={'хабарлайды': {'frequency': 1}}
# Lemma: Минск, Info: lemma='Минск' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'Минск': {'frequency': 1}}
# Lemma: Лукашенко, Info: lemma='Лукашенко' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom|Gender=Masc'] word_forms={'Лукашенко': {'frequency': 1}}
# Lemma: келіссөз, Info: lemma='келіссөз' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'келіссөз': {'frequency': 1}}
# Lemma: Беларусь, Info: lemma='Беларусь' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'Беларусь': {'frequency': 1}}
# Lemma: Ресей, Info: lemma='Ресей' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'Ресей': {'frequency': 1}}
# Lemma: айтыу, Info: lemma='айтыу' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'айтуынша': {'frequency': 1}}
# Lemma: Александр, Info: lemma='Александр' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom|Gender=Masc'] word_forms={'Александр': {'frequency': 1}}
# Lemma: е, Info: lemma='е' lemma_freq=1 pos=['AUX'] morph_features=['Case=Dat|Number[psor]=Plur,Sing|Person[psor]=3|Tense=Past|VerbForm=Ger'] word_forms={'екеніне': {'frequency': 1}}
# Lemma: жағдай, Info: lemma='жағдай' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'жағдай': {'frequency': 1}}
# Lemma: ТАСС, Info: lemma='ТАСС' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'ТАСС': {'frequency': 1}}
# Lemma: барлық, Info: lemma='барлық' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'барлық': {'frequency': 1}}
# Lemma: жаса, Info: lemma='жаса' lemma_freq=1 pos=['VERB'] morph_features=['Case=Dat|VerbForm=Ger'] word_forms={'жасауға': {'frequency': 1}}
# Lemma: Путин, Info: lemma='Путин' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Dat'] word_forms={'Путинге': {'frequency': 1}}
# Lemma: Украина, Info: lemma='Украина' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'Украина': {'frequency': 1}}
# Lemma: сендір, Info: lemma='сендір' lemma_freq=1 pos=['VERB'] morph_features=['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'] word_forms={'сендірді': {'frequency': 1}}
# Lemma: Кремль, Info: lemma='Кремль' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'Кремль': {'frequency': 1}}
# Lemma: метр, Info: lemma='метр' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'метр': {'frequency': 1}}
# Lemma: 130, Info: lemma='130' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Card'] word_forms={'130': {'frequency': 1}}
# Lemma: ол, Info: lemma='ол' lemma_freq=1 pos=['PRON'] morph_features=['Case=Gen|Number=Sing|Person=3|PronType=Prs'] word_forms={'Оның': {'frequency': 1}}
# Lemma: арқылы, Info: lemma='арқылы' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'арқылы': {'frequency': 1}}
# Lemma: көтер, Info: lemma='көтер' lemma_freq=1 pos=['VERB'] morph_features=['Aspect=Perf|VerbForm=Conv'] word_forms={'көтеріліп': {'frequency': 1}}
# Lemma: іш, Info: lemma='іш' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3', 'Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'ішінде': {'frequency': 1}, 'ішінен': {'frequency': 1}}
# Lemma: бол, Info: lemma='бол' lemma_freq=1 pos=['AUX'] morph_features=['Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'] word_forms={'болады': {'frequency': 1}}
# Lemma: жақ, Info: lemma='жақ' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc'] word_forms={'жақтағы': {'frequency': 1}}
# Lemma: тамаша, Info: lemma='тамаша' lemma_freq=1 pos=['VERB'] morph_features=['Case=Dat|VerbForm=Ger'] word_forms={'тамашалауға': {'frequency': 1}}
# Lemma: лифт, Info: lemma='лифт' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'лифт': {'frequency': 1}}
# Lemma: мұнара, Info: lemma='мұнара' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'мұнара': {'frequency': 1}}
# Lemma: қала, Info: lemma='қала' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Acc'] word_forms={'қаланы': {'frequency': 1}}
# Lemma: -, Info: lemma='-' lemma_freq=2 pos=['PUNCT'] morph_features=[None] word_forms={'-': {'frequency': 2}}
# Lemma: сол, Info: lemma='сол' lemma_freq=1 pos=['DET'] morph_features=['PronType=Dem'] word_forms={'сол': {'frequency': 1}}
# Lemma: жоғары, Info: lemma='жоғары' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'жоғары': {'frequency': 1}}
# Lemma: биіктік, Info: lemma='биіктік' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'Биіктігі': {'frequency': 1}}
# Lemma: биік, Info: lemma='биік' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Abl'] word_forms={'биіктен': {'frequency': 1}}
# Lemma: картоп, Info: lemma='картоп' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'картоп': {'frequency': 1}}
# Lemma: тонна, Info: lemma='тонна' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Abl'] word_forms={'тоннадан': {'frequency': 1}}
# Lemma: ;, Info: lemma=';' lemma_freq=1 pos=['PUNCT'] morph_features=[None] word_forms={';': {'frequency': 1}}
# Lemma: мың, Info: lemma='мың' lemma_freq=3 pos=['NUM'] morph_features=['NumType=Card'] word_forms={'мың': {'frequency': 3}}
# Lemma: қырыққабат, Info: lemma='қырыққабат' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'қырыққабат': {'frequency': 1}}
# Lemma: қор, Info: lemma='қор' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'қоры': {'frequency': 1}}
# Lemma: аса, Info: lemma='аса' lemma_freq=1 pos=['VERB'] morph_features=['Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'] word_forms={'асады': {'frequency': 1}}
# Lemma: болжам, Info: lemma='болжам' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'болжамы': {'frequency': 1}}
# Lemma: тоннан, Info: lemma='тоннан' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Acc'] word_forms={'тоннаны': {'frequency': 1}}
# Lemma: ег, Info: lemma='ег' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'егін': {'frequency': 1}}
# Lemma: 170, Info: lemma='170' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Card'] word_forms={'170': {'frequency': 1}}
# Lemma: айт, Info: lemma='айт' lemma_freq=1 pos=['VERB'] morph_features=['Tense=Past|VerbForm=Part'] word_forms={'айтқанда': {'frequency': 1}}
# Lemma: Атап, Info: lemma='Атап' lemma_freq=1 pos=['X'] morph_features=[None] word_forms={'Атап': {'frequency': 1}}
# Lemma: құра, Info: lemma='құра' lemma_freq=1 pos=['VERB'] morph_features=['Aspect=Hab|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'] word_forms={'құрайды': {'frequency': 1}}
# Lemma: тон, Info: lemma='тон' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'тонна': {'frequency': 1}}
# Lemma: ерте, Info: lemma='ерте' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'ерте': {'frequency': 1}}
# Lemma: 32, Info: lemma='32' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Card'] word_forms={'32': {'frequency': 1}}
# Lemma: сақта, Info: lemma='сақта' lemma_freq=1 pos=['VERB'] morph_features=['Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Pass'] word_forms={'сақталуда': {'frequency': 1}}
# Lemma: 380, Info: lemma='380' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Card'] word_forms={'380': {'frequency': 1}}
# Lemma: Бесембаев, Info: lemma='Бесембаев' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Ins|Gender=Masc'] word_forms={'Бесембаевамен': {'frequency': 1}}
# Lemma: отыр, Info: lemma='отыр' lemma_freq=1 pos=['VERB'] morph_features=['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin'] word_forms={'отырды': {'frequency': 1}}
# Lemma: олқылық, Info: lemma='олқылық' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Gen'] word_forms={'олқылықтың': {'frequency': 1}}
# Lemma: орнын, Info: lemma='орнын' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'орнын': {'frequency': 1}}
# Lemma: бұл, Info: lemma='бұл' lemma_freq=1 pos=['DET'] morph_features=['PronType=Dem'] word_forms={'Бұл': {'frequency': 1}}
# Lemma: РҚБ, Info: lemma='РҚБ' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'РҚБ': {'frequency': 1}}
# Lemma: медиация, Info: lemma='медиация' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'медиация': {'frequency': 1}}
# Lemma: СҚО, Info: lemma='СҚО' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'СҚО': {'frequency': 1}}
# Lemma: меморанду, Info: lemma='меморанду' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Dat'] word_forms={'меморандумға': {'frequency': 1}}
# Lemma: мақсат, Info: lemma='мақсат' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'мақсатында': {'frequency': 1}}
# Lemma: солтүстік, Info: lemma='солтүстік' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'Солтүстік': {'frequency': 1}}
# Lemma: орталық, Info: lemma='орталық' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'орталығы': {'frequency': 1}}
# Lemma: толтыр, Info: lemma='толтыр' lemma_freq=1 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger'] word_forms={'толтыру': {'frequency': 1}}
# Lemma: прокуратура, Info: lemma='прокуратура' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'прокуратурасы': {'frequency': 1}}
# Lemma: көлік, Info: lemma='көлік' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'көлік': {'frequency': 1}}
# Lemma: би, Info: lemma='би' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom|Gender=Masc'] word_forms={'би': {'frequency': 1}}
# Lemma: халықаралық, Info: lemma='халықаралық' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'Халықаралық': {'frequency': 1}}
# Lemma: алтын, Info: lemma='алтын' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom|Gender=Masc'] word_forms={'Алтын': {'frequency': 1}}
# Lemma: 2022, Info: lemma='2022' lemma_freq=1 pos=['NUM'] morph_features=['NumType=Ord'] word_forms={'2022': {'frequency': 1}}
# Lemma: сақтандыр, Info: lemma='сақтандыр' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Gen'] word_forms={'сақтандырудың': {'frequency': 1}}
# Lemma: маңызды, Info: lemma='маңызды' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'маңызды': {'frequency': 1}}
# Lemma: қатар, Info: lemma='қатар' lemma_freq=1 pos=['ADP'] morph_features=[None] word_forms={'қатар': {'frequency': 1}}
# Lemma: нарық, Info: lemma='нарық' lemma_freq=2 pos=['NOUN'] morph_features=['Case=Acc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'нарығын': {'frequency': 2}}
# Lemma: қағаз, Info: lemma='қағаз' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number=Plur'] word_forms={'қағаздар': {'frequency': 1}}
# Lemma: сақтандыру, Info: lemma='сақтандыру' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'сақтандыру': {'frequency': 1}}
# Lemma: бірлес, Info: lemma='бірлес' lemma_freq=1 pos=['VERB'] morph_features=['Tense=Past|VerbForm=Part'] word_forms={'бірлескен': {'frequency': 1}}
# Lemma: зейнетақ, Info: lemma='зейнетақ' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom'] word_forms={'зейнетақы': {'frequency': 1}}
# Lemma: өнім, Info: lemma='өнім' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'өнімі': {'frequency': 1}}
# Lemma: жаңа, Info: lemma='жаңа' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'жаңа': {'frequency': 1}}
# Lemma: сонымен, Info: lemma='сонымен' lemma_freq=1 pos=['PRON'] morph_features=['Case=Ins|PronType=Dem'] word_forms={'Сонымен': {'frequency': 1}}
# Lemma: аннуитет, Info: lemma='аннуитет' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Nom|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'аннуитеті': {'frequency': 1}}
# Lemma: ҚР, Info: lemma='ҚР' lemma_freq=1 pos=['PROPN'] morph_features=['Case=Nom'] word_forms={'ҚР': {'frequency': 1}}
# Lemma: қыркүйек, Info: lemma='қыркүйек' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Abl|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'қыркүйегінен': {'frequency': 1}}
# Lemma: дамыт, Info: lemma='дамыт' lemma_freq=1 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger'] word_forms={'дамыту': {'frequency': 1}}
# Lemma: ретте, Info: lemma='ретте' lemma_freq=1 pos=['VERB'] morph_features=['Case=Nom|VerbForm=Ger'] word_forms={'реттеу': {'frequency': 1}}
# Lemma: өмірд, Info: lemma='өмірд' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Acc'] word_forms={'өмірді': {'frequency': 1}}
# Lemma: аяыс, Info: lemma='аяыс' lemma_freq=1 pos=['NOUN'] morph_features=['Case=Loc|Number[psor]=Plur,Sing|Person[psor]=3'] word_forms={'аясында': {'frequency': 1}}
# Lemma: баста, Info: lemma='баста' lemma_freq=1 pos=['VERB'] morph_features=['Aspect=Perf|VerbForm=Conv'] word_forms={'бастап': {'frequency': 1}}
# Lemma: әлеуметтік, Info: lemma='әлеуметтік' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'әлеуметтік': {'frequency': 1}}
# Lemma: бағалы, Info: lemma='бағалы' lemma_freq=1 pos=['ADJ'] morph_features=[None] word_forms={'бағалы': {'frequency': 1}}
